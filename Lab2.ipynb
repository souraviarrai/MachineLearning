# %% [markdown]
# **LabWork on  Data Inspection and Handling Missing Values**

# %% [markdown]
# Inspecting data by loading data

# %%
import pandas as pd

# %%
#Reading excel file
df=pd.read_excel('yelp.xlsx', sheet_name='yelp_data')
df
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#                                                   name      category_0  \
# 0                         China Sea Chinese Restaurant     Restaurants
# 1                                 Discount Tire Center           Tires
# 2                                         Frankfurters     Restaurants
# 3                                    Fred Dietz Floral        Shopping
# 4                                        Kuhn's Market            Food
# ..                                                 ...             ...
# 595  Republic Services of Southern Nevada Recycling...  Local Services
# 596                                       SA Recycling  Local Services
# 597                                    Jack In the Box     Restaurants
# 598                               Custom Hearth & Door        Shopping
# ...

# %% [markdown]
# To Understanding the data

# %%
df.head()
# Out:
#                            name   category_0       category_1 take_out  \
# 0  China Sea Chinese Restaurant  Restaurants          Chinese     True
# 1          Discount Tire Center        Tires       Automotive    False
# 2                  Frankfurters  Restaurants         Hot Dogs     True
# 3             Fred Dietz Floral     Shopping  Flowers & Gifts    False
# 4                 Kuhn's Market         Food          Grocery    False
#
#    review_count  stars
# 0          11.0    2.5
# 1          24.0    4.5
# 2           3.0    4.5
# 3           6.0    4.0
# 4           8.0    3.5

# %%
df.head(20)
# Out:
#                             name                    category_0  \
# 0   China Sea Chinese Restaurant                   Restaurants
# 1           Discount Tire Center                         Tires
# 2                   Frankfurters                   Restaurants
# 3              Fred Dietz Floral                      Shopping
# 4                  Kuhn's Market                          Food
# 5                 Lincoln Bakery                          Food
# 6               Luigi's Pizzeria                   Restaurants
# 7     Mane Attractions Unlimited                   Hair Salons
# 8            R & B's Pizza Place                   Restaurants
# 9                     Rusty Nail                   Restaurants
# 10                    Star Nails                 Beauty & Spas
# 11                          Vivo                   Restaurants
# 12                 Emil's Lounge                          Bars
# 13          Grand View Golf Club                   Active Life
# ...

# %%
df.tail()
# Out:
#                                                   name      category_0  \
# 595  Republic Services of Southern Nevada Recycling...  Local Services
# 596                                       SA Recycling  Local Services
# 597                                    Jack In the Box     Restaurants
# 598                               Custom Hearth & Door        Shopping
# 599                                   A Sunrise Towing      Automotive
#
#                           category_1 take_out  review_count  stars
# 595                 Recycling Center    False           7.0    2.5
# 596                 Recycling Center    False           3.0    1.5
# 597                        Fast Food     True          12.0    3.0
# 598  Heating & Air Conditioning/HVAC    False           9.0    4.0
# 599                           Towing    False           4.0    1.0

# %%
df.tail(10)
# Out:
#                                                   name      category_0  \
# 590                            Rainbow Medical Centers         Doctors
# 591                                      Tortas El Rey       Fast Food
# 592                                      Passion Nails   Beauty & Spas
# 593                             Sporting Chance Saloon            Bars
# 594                                     Domino's Pizza      Sandwiches
# 595  Republic Services of Southern Nevada Recycling...  Local Services
# 596                                       SA Recycling  Local Services
# 597                                    Jack In the Box     Restaurants
# 598                               Custom Hearth & Door        Shopping
# 599                                   A Sunrise Towing      Automotive
#
#                           category_1 take_out  review_count  stars
# 590                  Medical Centers    False           5.0    1.5
# ...

# %%
df[10:20]
# Out:
#                             name                    category_0  \
# 10                    Star Nails                 Beauty & Spas
# 11                          Vivo                   Restaurants
# 12                 Emil's Lounge                          Bars
# 13          Grand View Golf Club                   Active Life
# 14            Advance Auto Parts                    Automotive
# 15         Alexion's Bar & Grill                          Bars
# 16              Alteration World                Local Services
# 17                      Amerifit                   Active Life
# 18  Barb's Country Junction Cafe                   Restaurants
# 19         Carnegie Free Library  Public Services & Government
#
#                 category_1 take_out  review_count  stars
# 10             Nail Salons    False           7.0    2.5
# 11                 Italian      NaN           3.0    NaN
# 12          American (New)     True          26.0    4.5
# ...

# %%
df.shape
# Out:
# (600, 6)

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 3600

# %%
df.columns
# Out:
# Index(['name', 'category_0', 'category_1', 'take_out', 'review_count',
#        'stars'],
#       dtype='object')

# %%
df.dtypes
# Out:
# name             object
# category_0       object
# category_1       object
# take_out         object
# review_count    float64
# stars           float64
# dtype: object

# %%
df['stars'].dtypes
# Out:
# dtype('float64')

# %%
df.count()
# Out:
# name            600
# category_0      600
# category_1      600
# take_out        586
# review_count    594
# stars           591
# dtype: int64

# %% [markdown]
# Summarising and computing descriptive statistics

# %%
df.sum()
# Out:
# name            China Sea Chinese RestaurantDiscount Tire Cent...
# category_0      RestaurantsTiresRestaurantsShoppingFoodFoodRes...
# category_1      ChineseAutomotiveHot DogsFlowers & GiftsGrocer...
# take_out                                                      186
# review_count                                              20202.0
# stars                                                      2059.5
# dtype: object

# %%
df.sum(axis = 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# 0      13.5
# 1      28.5
# 2       7.5
# 3      10.0
# 4      11.5
#        ...
# 595     9.5
# 596     4.5
# 597    15.0
# 598    13.0
# 599     5.0
# Length: 600, dtype: float64

# %%
df[['review_count','stars']].agg(['min','mean','max','std'])
# Out:
#       review_count     stars
# min       3.000000  1.000000
# mean     34.010101  3.484772
# max    1305.000000  5.000000
# std      87.305321  0.957453

# %%
df.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# take_out         0.317406
# review_count    34.010101
# stars            3.484772
# dtype: float64

# %%
df.mean(axis = 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# 0       6.75
# 1      14.25
# 2       3.75
# 3       5.00
# 4       5.75
#        ...
# 595     4.75
# 596     2.25
# 597     7.50
# 598     6.50
# 599     2.50
# Length: 600, dtype: float64

# %%
df.mode()
# Out:
#           name category_0 category_1 take_out  review_count  stars
# 0  Giant Eagle   Shopping      Pizza    False           3.0    3.5

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                                                   name      category_0  \
# 0                         China Sea Chinese Restaurant     Restaurants
# 1                                 Discount Tire Center           Tires
# 2                                         Frankfurters     Restaurants
# 3                                    Fred Dietz Floral        Shopping
# 4                                        Kuhn's Market            Food
# ..                                                 ...             ...
# 595  Republic Services of Southern Nevada Recycling...  Local Services
# 596                                       SA Recycling  Local Services
# 597                                    Jack In the Box     Restaurants
# 598                               Custom Hearth & Door        Shopping
# 599                                   A Sunrise Towing      Automotive
#
#                           category_1 take_out  review_count  stars
# ...

# %%
df['name'].describe()
# Out:
# count             600
# unique            566
# top       Giant Eagle
# freq                7
# Name: name, dtype: object

# %% [markdown]
# Looking for missing data

# %%
df.isnull()
# Out:
#       name  category_0  category_1  take_out  review_count  stars
# 0    False       False       False     False         False  False
# 1    False       False       False     False         False  False
# 2    False       False       False     False         False  False
# 3    False       False       False     False         False  False
# 4    False       False       False     False         False  False
# ..     ...         ...         ...       ...           ...    ...
# 595  False       False       False     False         False  False
# 596  False       False       False     False         False  False
# 597  False       False       False     False         False  False
# 598  False       False       False     False         False  False
# 599  False       False       False     False         False  False
#
# [600 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# name             0
# category_0       0
# category_1       0
# take_out        14
# review_count     6
# stars            9
# dtype: int64

# %%
df.isna().sum()
# Out:
# name             0
# category_0       0
# category_1       0
# take_out        14
# review_count     6
# stars            9
# dtype: int64

# %% [markdown]
# Handling Missing Value (Numerical)

# %%
 #dropna() drops any row containing missing values. 
newdf = df.dropna()
newdf
# Out:
#                                                   name      category_0  \
# 0                         China Sea Chinese Restaurant     Restaurants
# 1                                 Discount Tire Center           Tires
# 2                                         Frankfurters     Restaurants
# 3                                    Fred Dietz Floral        Shopping
# 4                                        Kuhn's Market            Food
# ..                                                 ...             ...
# 595  Republic Services of Southern Nevada Recycling...  Local Services
# 596                                       SA Recycling  Local Services
# 597                                    Jack In the Box     Restaurants
# 598                               Custom Hearth & Door        Shopping
# 599                                   A Sunrise Towing      Automotive
#
#                           category_1 take_out  review_count  stars
# ...

# %%
newdf.shape
# Out:
# (572, 6)

# %%
filtered_df = df[df.notnull()]
filtered_df.shape
# Out:
# (600, 6)

# %%
newdf1 = df.dropna(axis = 1)
newdf1.head()
# Out:
#                            name   category_0       category_1
# 0  China Sea Chinese Restaurant  Restaurants          Chinese
# 1          Discount Tire Center        Tires       Automotive
# 2                  Frankfurters  Restaurants         Hot Dogs
# 3             Fred Dietz Floral     Shopping  Flowers & Gifts
# 4                 Kuhn's Market         Food          Grocery

# %% [markdown]
# Filling Missing value

# %%
#using fillna() without any paramters
df.fillna(0)
# Out:
#                                                   name      category_0  \
# 0                         China Sea Chinese Restaurant     Restaurants
# 1                                 Discount Tire Center           Tires
# 2                                         Frankfurters     Restaurants
# 3                                    Fred Dietz Floral        Shopping
# 4                                        Kuhn's Market            Food
# ..                                                 ...             ...
# 595  Republic Services of Southern Nevada Recycling...  Local Services
# 596                                       SA Recycling  Local Services
# 597                                    Jack In the Box     Restaurants
# 598                               Custom Hearth & Door        Shopping
# 599                                   A Sunrise Towing      Automotive
#
#                           category_1 take_out  review_count  stars
# ...

# %%
#Replacing missing value by mode
df.fillna(df.mode())
# Out:
#                                                   name      category_0  \
# 0                         China Sea Chinese Restaurant     Restaurants
# 1                                 Discount Tire Center           Tires
# 2                                         Frankfurters     Restaurants
# 3                                    Fred Dietz Floral        Shopping
# 4                                        Kuhn's Market            Food
# ..                                                 ...             ...
# 595  Republic Services of Southern Nevada Recycling...  Local Services
# 596                                       SA Recycling  Local Services
# 597                                    Jack In the Box     Restaurants
# 598                               Custom Hearth & Door        Shopping
# 599                                   A Sunrise Towing      Automotive
#
#                           category_1 take_out  review_count  stars
# ...
