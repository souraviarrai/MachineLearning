# %%
import pandas as pd
series = pd.Series([2,4,6,8])

# %%
series
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# dtype: int64

# %%
data = {'name':['sonam','pema','karma'], 'age':[20,30,40], 'marks':[60,70,80]}
df = pd.DataFrame(data)
df
# Out:
#     name  age  marks
# 0  sonam   20     60
# 1   pema   30     70
# 2  karma   40     80

# %%
data = pd.read_excel("yelp.xlsx")
data
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#                                                   name      category_0  \
# 0                         China Sea Chinese Restaurant     Restaurants
# 1                                 Discount Tire Center           Tires
# 2                                         Frankfurters     Restaurants
# 3                                    Fred Dietz Floral        Shopping
# 4                                        Kuhn's Market            Food
# ..                                                 ...             ...
# 595  Republic Services of Southern Nevada Recycling...  Local Services
# 596                                       SA Recycling  Local Services
# 597                                    Jack In the Box     Restaurants
# 598                               Custom Hearth & Door        Shopping
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=600, step=1)

# %%
data.columns
# Out:
# Index(['name', 'category_0', 'category_1', 'take_out', 'review_count',
#        'stars'],
#       dtype='object')

# %%
data.dtypes
# Out:
# name             object
# category_0       object
# category_1       object
# take_out         object
# review_count    float64
# stars           float64
# dtype: object

# %%
data.shape
# Out:
# (600, 6)

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   age     3 non-null      int64
#  2   marks   3 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 200.0+ bytes

# %%
data.values
# Out:
# array([['China Sea Chinese Restaurant', 'Restaurants', 'Chinese', True,
#         11.0, 2.5],
#        ['Discount Tire Center', 'Tires', 'Automotive', False, 24.0, 4.5],
#        ['Frankfurters', 'Restaurants', 'Hot Dogs', True, 3.0, 4.5],
#        ...,
#        ['Jack In the Box', 'Restaurants', 'Fast Food', True, 12.0, 3.0],
#        ['Custom Hearth & Door', 'Shopping',
#         'Heating & Air Conditioning/HVAC', False, 9.0, 4.0],
#        ['A Sunrise Towing', 'Automotive', 'Towing', False, 4.0, 1.0]],
#       dtype=object)

# %%
data.head()
# Out:
#                            name   category_0       category_1 take_out  \
# 0  China Sea Chinese Restaurant  Restaurants          Chinese     True
# 1          Discount Tire Center        Tires       Automotive    False
# 2                  Frankfurters  Restaurants         Hot Dogs     True
# 3             Fred Dietz Floral     Shopping  Flowers & Gifts    False
# 4                 Kuhn's Market         Food          Grocery    False
#
#    review_count  stars
# 0          11.0    2.5
# 1          24.0    4.5
# 2           3.0    4.5
# 3           6.0    4.0
# 4           8.0    3.5

# %%
data.describe()
# Out:
#        review_count       stars
# count    594.000000  591.000000
# mean      34.010101    3.484772
# std       87.305321    0.957453
# min        3.000000    1.000000
# 25%        5.000000    3.000000
# 50%       10.000000    3.500000
# 75%       26.000000    4.000000
# max     1305.000000    5.000000

# %%
data.loc[:,'take_out']
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 595    False
# 596    False
# 597     True
# 598    False
# 599    False
# Name: take_out, Length: 600, dtype: object

# %%
df.last_three = data.iloc[:5,-3]
df.last_three
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.
# 0     True
# 1    False
# 2     True
# 3    False
# 4    False
# Name: take_out, dtype: object

# %%
df_index123 = data.iloc[:5,:3]
df_index123
# Out:
#                            name   category_0       category_1
# 0  China Sea Chinese Restaurant  Restaurants          Chinese
# 1          Discount Tire Center        Tires       Automotive
# 2                  Frankfurters  Restaurants         Hot Dogs
# 3             Fred Dietz Floral     Shopping  Flowers & Gifts
# 4                 Kuhn's Market         Food          Grocery

# %%
df_last4cols = data.iloc[:5,2:]
df_last4cols
# Out:
#         category_1 take_out  review_count  stars
# 0          Chinese     True          11.0    2.5
# 1       Automotive    False          24.0    4.5
# 2         Hot Dogs     True           3.0    4.5
# 3  Flowers & Gifts    False           6.0    4.0
# 4          Grocery    False           8.0    3.5

# %%
(data['review_count']<10).sum()
# Out:
# 279

# %%
(data['review_count']>20).sum()
# Out:
# 185

# %%
df_category = data.filter(regex = 'cate', axis = 1)
df_category = data.filter(like = 'cate')
df_category
# Out:
#          category_0                       category_1
# 0       Restaurants                          Chinese
# 1             Tires                       Automotive
# 2       Restaurants                         Hot Dogs
# 3          Shopping                  Flowers & Gifts
# 4              Food                          Grocery
# ..              ...                              ...
# 595  Local Services                 Recycling Center
# 596  Local Services                 Recycling Center
# 597     Restaurants                        Fast Food
# 598        Shopping  Heating & Air Conditioning/HVAC
# 599      Automotive                           Towing
#
# [600 rows x 2 columns]

# %%
Third_row = data.iloc[3:3,:]
Third_row
# Out:
# Empty DataFrame
# Columns: [name, category_0, category_1, take_out, review_count, stars]
# Index: []

# %%
last_rows = data.iloc[-12:,:]
last_rows
# Out:
#                                                   name      category_0  \
# 588                                   Rakeman Plumbing        Shopping
# 589                           Ace World Wide of Nevada          Movers
# 590                            Rainbow Medical Centers         Doctors
# 591                                      Tortas El Rey       Fast Food
# 592                                      Passion Nails   Beauty & Spas
# 593                             Sporting Chance Saloon            Bars
# 594                                     Domino's Pizza      Sandwiches
# 595  Republic Services of Southern Nevada Recycling...  Local Services
# 596                                       SA Recycling  Local Services
# 597                                    Jack In the Box     Restaurants
# 598                               Custom Hearth & Door        Shopping
# 599                                   A Sunrise Towing      Automotive
#
# ...

# %%
data.drop(columns = ['name','category_1','review_count'])
# Out:
#          category_0 take_out  stars
# 0       Restaurants     True    2.5
# 1             Tires    False    4.5
# 2       Restaurants     True    4.5
# 3          Shopping    False    4.0
# 4              Food    False    3.5
# ..              ...      ...    ...
# 595  Local Services    False    2.5
# 596  Local Services    False    1.5
# 597     Restaurants     True    3.0
# 598        Shopping    False    4.0
# 599      Automotive    False    1.0
#
# [600 rows x 3 columns]

# %%
data.drop(data.index[data['category_1'] == 'Chinese'] | data.index[data['category_1'] == 'Pizza'] | data.index[data['category_1'] == 'Casinos'], inplace = True)
data
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#   """Entry point for launching an IPython kernel.
#                                                   name      category_0  \
# 1                                 Discount Tire Center           Tires
# 2                                         Frankfurters     Restaurants
# 3                                    Fred Dietz Floral        Shopping
# 4                                        Kuhn's Market            Food
# 5                                       Lincoln Bakery            Food
# ..                                                 ...             ...
# 595  Republic Services of Southern Nevada Recycling...  Local Services
# 596                                       SA Recycling  Local Services
# ...

# %%
append = data
multiple_of_5df = append.filter(regex = '5$', axis = 0)
multiple_of_10df = append.filter(regex = '0$', axis = 0)
multiple_of_5df.shape
multiple_of_10df.shape
result = pd.concat([multiple_of_10df, multiple_of_5df])
result.tail()
result.shape
multiple_of_5df
# Out:
#                                                   name  \
# 5                                       Lincoln Bakery
# 15                               Alexion's Bar & Grill
# 25                                      Heidelberg B P
# 35                                  Weinberg Lisa, DMD
# 45                       First Class Limousine Service
# 55                                          McDonald's
# 65                                           Sing Sing
# 75                                             Wendy's
# 85                                      Pierogies Plus
# 95                                 Aamco Transmissions
# 115                                   Buon Giorno Cafe
# 125             Chinese Acupuncture & Herbs Center LLC
# 135                            Dan Cercone Hairstyling
# 145                                  Econowash Laundry
# 155                                           Galleria
# 165                                    Hairdressers II
# ...

# %%
df1 = pd.DataFrame({'President':['Audrey','Kinga']}, index = ["GCIT", "Sherubtse"])
df2 = pd.DataFrame({'Location':['Mongar','Kanglung']},index = ["GCIT","Sherubtse"])
result1 = pd.concat([df1,df2], axis = 1)
result1
# Out:
#           President  Location
# GCIT         Audrey    Mongar
# Sherubtse     Kinga  Kanglung

# %%
data_df = pd.DataFrame({'name':['sonam','Tshering','Pema','Leki','Ugyen'], 'age':[20,30,21,23,35], 'marks':[45,55,60,45,55]})
data_df
# Out:
#        name  age  marks
# 0     sonam   20     45
# 1  Tshering   30     55
# 2      Pema   21     60
# 3      Leki   23     45
# 4     Ugyen   35     55

# %%
data.sort_values(by = 'review_count', ascending = False)
# Out:
#                               name          category_0  \
# 534                         Ichiza         Restaurants
# 537                       Pho So 1         Restaurants
# 434                   Omelet House  Breakfast & Brunch
# 507          Luv It Frozen Custard                Food
# 439  Palace Station Hotel & Casino     Hotels & Travel
# ..                             ...                 ...
# 492                      Rebel Oil          Automotive
# 15           Alexion's Bar & Grill                Bars
# 40           Dick's Sporting Goods      Sporting Goods
# 115               Buon Giorno Cafe         Restaurants
# 174      Jade 99 Asian Supermarket                Food
#
#                     category_1 take_out  review_count  stars
# 534                   Japanese     True        1305.0    4.0
# 537                 Vietnamese     True         763.0    3.5
# 434     American (Traditional)     True         703.0    4.5
# ...

# %%
data.sort_values(by = 'review_count', ascending = True)
# Out:
#                                name      category_0              category_1  \
# 226       Pittsburgh Eye Associates    Optometrists        Ophthalmologists
# 210  Novak Berkowitz & Rosenberg MD         Doctors        Ophthalmologists
# 84                      Pat Catan's        Shopping            Art Supplies
# 543                     China China        Shopping           Home & Garden
# 217             Payless Shoe Source        Shopping                 Fashion
# ..                              ...             ...                     ...
# 534                          Ichiza     Restaurants                Japanese
# 15            Alexion's Bar & Grill            Bars  American (Traditional)
# 40            Dick's Sporting Goods  Sporting Goods                 Fashion
# 115                Buon Giorno Cafe     Restaurants                 Italian
# 174       Jade 99 Asian Supermarket            Food                 Grocery
#
#     take_out  review_count  stars
# ...

# %%
data.sort_index(axis = 1, ascending = False)
# Out:
#     take_out  stars  review_count  \
# 1      False    4.5          24.0
# 2       True    4.5           3.0
# 3      False    4.0           6.0
# 4      False    3.5           8.0
# 5       True    4.0          25.0
# ..       ...    ...           ...
# 595    False    2.5           7.0
# 596    False    1.5           3.0
# 597     True    3.0          12.0
# 598    False    4.0           9.0
# 599    False    1.0           4.0
#
#                                                   name  \
# 1                                 Discount Tire Center
# 2                                         Frankfurters
# 3                                    Fred Dietz Floral
# 4                                        Kuhn's Market
# 5                                       Lincoln Bakery
# ..                                                 ...
# 595  Republic Services of Southern Nevada Recycling...
# 596                                       SA Recycling
# ...

# %%
data.sort_index(axis = 1, ascending = False)
# Out:
#     take_out  stars  review_count  \
# 1      False    4.5          24.0
# 2       True    4.5           3.0
# 3      False    4.0           6.0
# 4      False    3.5           8.0
# 5       True    4.0          25.0
# ..       ...    ...           ...
# 595    False    2.5           7.0
# 596    False    1.5           3.0
# 597     True    3.0          12.0
# 598    False    4.0           9.0
# 599    False    1.0           4.0
#
#                                                   name  \
# 1                                 Discount Tire Center
# 2                                         Frankfurters
# 3                                    Fred Dietz Floral
# 4                                        Kuhn's Market
# 5                                       Lincoln Bakery
# ..                                                 ...
# 595  Republic Services of Southern Nevada Recycling...
# 596                                       SA Recycling
# ...

# %%
data.rename(columns = {"resturant_name":"name", "category_0":"type_1", "category_1":"type_2","take_out":"review", "review_count":"delivery", "stars":"rating"})
# Out:
#                                                   name          type_1  \
# 1                                 Discount Tire Center           Tires
# 2                                         Frankfurters     Restaurants
# 3                                    Fred Dietz Floral        Shopping
# 4                                        Kuhn's Market            Food
# 5                                       Lincoln Bakery            Food
# ..                                                 ...             ...
# 595  Republic Services of Southern Nevada Recycling...  Local Services
# 596                                       SA Recycling  Local Services
# 597                                    Jack In the Box     Restaurants
# 598                               Custom Hearth & Door        Shopping
# 599                                   A Sunrise Towing      Automotive
#
#                               type_2 review  delivery  rating
# ...

# %%
data.duplicated()
# Out:
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 595    False
# 596    False
# 597    False
# 598    False
# 599    False
# Length: 554, dtype: bool

# %%
data.duplicated(subset = ['name'])
# Out:
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 595    False
# 596    False
# 597     True
# 598    False
# 599    False
# Length: 554, dtype: bool

# %%
data.drop_duplicates()
# Out:
#                                                   name      category_0  \
# 1                                 Discount Tire Center           Tires
# 2                                         Frankfurters     Restaurants
# 3                                    Fred Dietz Floral        Shopping
# 4                                        Kuhn's Market            Food
# 5                                       Lincoln Bakery            Food
# ..                                                 ...             ...
# 595  Republic Services of Southern Nevada Recycling...  Local Services
# 596                                       SA Recycling  Local Services
# 597                                    Jack In the Box     Restaurants
# 598                               Custom Hearth & Door        Shopping
# 599                                   A Sunrise Towing      Automotive
#
#                           category_1 take_out  review_count  stars
# ...

# %%
data.drop_duplicates(subset = ['name'])
# Out:
#                                                   name      category_0  \
# 1                                 Discount Tire Center           Tires
# 2                                         Frankfurters     Restaurants
# 3                                    Fred Dietz Floral        Shopping
# 4                                        Kuhn's Market            Food
# 5                                       Lincoln Bakery            Food
# ..                                                 ...             ...
# 593                             Sporting Chance Saloon            Bars
# 595  Republic Services of Southern Nevada Recycling...  Local Services
# 596                                       SA Recycling  Local Services
# 598                               Custom Hearth & Door        Shopping
# 599                                   A Sunrise Towing      Automotive
#
#                           category_1 take_out  review_count  stars
# ...
